# %%
# import necessarry libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Add the parent directory to the system path
import os 
import sys 
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# importing modules from scripts
import scripts.labeling as l

# %%
df = pd.read_csv('../data/cleaned_data.csv')
df
# Out:
#       Unnamed: 0 Channel Title Channel Username    ID  \
# 0              0        ምርጥ ዕቃ        @MerttEka  6805
# 1              3        ምርጥ ዕቃ        @MerttEka  6802
# 2              4        ምርጥ ዕቃ        @MerttEka  6801
# 3              5        ምርጥ ዕቃ        @MerttEka  6800
# 4             10        ምርጥ ዕቃ        @MerttEka  6795
# ...          ...           ...              ...   ...
# 4152        5685        ምርጥ ዕቃ        @MerttEka    44
# 4153        5686        ምርጥ ዕቃ        @MerttEka    43
# 4154        5690        ምርጥ ዕቃ        @MerttEka    32
# 4155        5692        ምርጥ ዕቃ        @MerttEka    30
# 4156        5695        ምርጥ ዕቃ        @MerttEka    23
#
#                                                 Message  \
# 0                   \n\n ይሄንን ./  ተጭነው   ያድርጉ፣ ቤተሰብ ይሁኑ
# 1         \n\n የመኪና መዓዛ \n በፀሃይ ብርሃን ስለሚሰራ ቻርጅ ማድረግ ...
# 2      \n   /\n\n የፀጉር ማድረቂያ ፎን\n6000watt በጣም ፈጣን\nማ...
# 3      2  1    \n\n የሰላጣ እና የቺፕስ ማቅረቢያ\n\n 2400 ብር\n...
# 4           \n\n ዘመናዊ የልብስ ቁም ሳጥን\n በቀላሉ የሚገጣጠም የሚነቃ...
# ...                                                 ...
# 4152                                               2500
# 4153                                ዋጋ 2500\n0983063957
# 4154  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 4155  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4156                                        ለማዘዝ\n ://.
#
#                            Date                 Media Path
# 0     2024-09-26 16:38:22+00:00                        NaN
# 1     2024-09-26 16:16:51+00:00  photos\@MerttEka_6802.jpg
# 2     2024-09-26 12:31:45+00:00  photos\@MerttEka_6801.jpg
# 3     2024-09-26 09:22:02+00:00  photos\@MerttEka_6800.jpg
# 4     2024-09-26 08:31:44+00:00  photos\@MerttEka_6795.jpg
# ...                         ...                        ...
# 4152  2019-11-13 10:01:12+00:00                        NaN
# 4153  2019-11-13 10:00:40+00:00                        NaN
# 4154  2019-11-09 04:44:54+00:00                        NaN
# 4155  2019-10-31 07:06:25+00:00                        NaN
# 4156  2019-10-27 13:38:49+00:00                        NaN
#
# [4157 rows x 7 columns]

# %%
df.drop(columns='Unnamed: 0')
# Out:
#      Channel Title Channel Username    ID  \
# 0           ምርጥ ዕቃ        @MerttEka  6805
# 1           ምርጥ ዕቃ        @MerttEka  6802
# 2           ምርጥ ዕቃ        @MerttEka  6801
# 3           ምርጥ ዕቃ        @MerttEka  6800
# 4           ምርጥ ዕቃ        @MerttEka  6795
# ...            ...              ...   ...
# 4152        ምርጥ ዕቃ        @MerttEka    44
# 4153        ምርጥ ዕቃ        @MerttEka    43
# 4154        ምርጥ ዕቃ        @MerttEka    32
# 4155        ምርጥ ዕቃ        @MerttEka    30
# 4156        ምርጥ ዕቃ        @MerttEka    23
#
#                                                 Message  \
# 0                   \n\n ይሄንን ./  ተጭነው   ያድርጉ፣ ቤተሰብ ይሁኑ
# 1         \n\n የመኪና መዓዛ \n በፀሃይ ብርሃን ስለሚሰራ ቻርጅ ማድረግ ...
# 2      \n   /\n\n የፀጉር ማድረቂያ ፎን\n6000watt በጣም ፈጣን\nማ...
# 3      2  1    \n\n የሰላጣ እና የቺፕስ ማቅረቢያ\n\n 2400 ብር\n...
# 4           \n\n ዘመናዊ የልብስ ቁም ሳጥን\n በቀላሉ የሚገጣጠም የሚነቃ...
# ...                                                 ...
# 4152                                               2500
# 4153                                ዋጋ 2500\n0983063957
# 4154  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 4155  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 4156                                        ለማዘዝ\n ://.
#
#                            Date                 Media Path
# 0     2024-09-26 16:38:22+00:00                        NaN
# 1     2024-09-26 16:16:51+00:00  photos\@MerttEka_6802.jpg
# 2     2024-09-26 12:31:45+00:00  photos\@MerttEka_6801.jpg
# 3     2024-09-26 09:22:02+00:00  photos\@MerttEka_6800.jpg
# 4     2024-09-26 08:31:44+00:00  photos\@MerttEka_6795.jpg
# ...                         ...                        ...
# 4152  2019-11-13 10:01:12+00:00                        NaN
# 4153  2019-11-13 10:00:40+00:00                        NaN
# 4154  2019-11-09 04:44:54+00:00                        NaN
# 4155  2019-10-31 07:06:25+00:00                        NaN
# 4156  2019-10-27 13:38:49+00:00                        NaN
#
# [4157 rows x 6 columns]

# %%
# Drop rows with missing values in the Message columns 
df = df.dropna(subset=['Message'])

# %%
# confirm na is removed 
message_cleaned = df['Message'].isnull().sum()
print(f"Numer of NAN values in Message columns is {message_cleaned}")
# Out:
# Numer of NAN values in Message columns is 0

# %%
# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(l.label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22612\1803086290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Labeled_Message'] = df['Message'].apply(l.label_message_utf8_with_birr)
#    Unnamed: 0 Channel Title Channel Username    ID  \
# 0           0        ምርጥ ዕቃ        @MerttEka  6805
# 1           3        ምርጥ ዕቃ        @MerttEka  6802
# 2           4        ምርጥ ዕቃ        @MerttEka  6801
# 3           5        ምርጥ ዕቃ        @MerttEka  6800
# 4          10        ምርጥ ዕቃ        @MerttEka  6795
#
#                                              Message  \
# 0                \n\n ይሄንን ./  ተጭነው   ያድርጉ፣ ቤተሰብ ይሁኑ
# 1      \n\n የመኪና መዓዛ \n በፀሃይ ብርሃን ስለሚሰራ ቻርጅ ማድረግ ...
# 2   \n   /\n\n የፀጉር ማድረቂያ ፎን\n6000watt በጣም ፈጣን\nማ...
# 3   2  1    \n\n የሰላጣ እና የቺፕስ ማቅረቢያ\n\n 2400 ብር\n...
# 4        \n\n ዘመናዊ የልብስ ቁም ሳጥን\n በቀላሉ የሚገጣጠም የሚነቃ...
#
#                         Date                 Media Path  \
# 0  2024-09-26 16:38:22+00:00                        NaN
# 1  2024-09-26 16:16:51+00:00  photos\@MerttEka_6802.jpg
# 2  2024-09-26 12:31:45+00:00  photos\@MerttEka_6801.jpg
# 3  2024-09-26 09:22:02+00:00  photos\@MerttEka_6800.jpg
# 4  2024-09-26 08:31:44+00:00  photos\@MerttEka_6795.jpg
#
#                                      Labeled_Message
# 0             ይሄንን O\nተጭነው O\nያድርጉ፣ O\nቤተሰብ O\nይሁኑ O
# 1  የመኪና I-PRODUCT\nመዓዛ B-PRODUCT\nበፀሃይ O\nብርሃን O\...
# 2  የፀጉር I-PRODUCT\nማድረቂያ I-PRODUCT\nፎን B-PRODUCT\...
# 3  2 O\n1 O\nየሰላጣ O\nእና I-PRODUCT\nየቺፕስ I-PRODUCT...
# 4  ዘመናዊ O\nየልብስ O\nቁም O\nሳጥን O\nበቀላሉ O\nየሚገጣጠም O\...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = '../data/labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")

# %%
# Save the labeled data to a .conll file
conll_file_path = '../data/@mertteka_labeled_data.conll'
with open(conll_file_path, 'w', encoding='utf-8') as f:
    for labeled_message in df['Labeled_Message']:
        f.write(f"{labeled_message}\n\n")

print(f"Labeled data saved to {conll_file_path}")
# Out:
# Labeled data saved to ../data/@mertteka_labeled_data.conll
